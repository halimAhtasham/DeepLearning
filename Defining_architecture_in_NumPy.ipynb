# %% [markdown]
# <a href="https://colab.research.google.com/github/halimAhtasham/DeepLearning/blob/main/Defining_architecture_in_NumPy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Architecture: 2 inputs -> 4 hidden neurons -> 1 output neuron
import numpy as np
#Define the architecture
input_size = 2
hidden_size = 4
output_size = 1

# We initialize random weights for each connection
# W1: Connects Input to Hidden. Shape = (input_size, hidden_size)
W1 = np.random.randn(input_size, hidden_size)
b1 = np.zeros(hidden_size)

# W2: Connects Hidden to Output. Shape = (hidden_size, output_size)
W2 = np.random.randn(hidden_size, output_size)
b2 = np.zeros(output_size)

print("Architecture Defined!")
print(f"Weight 1 shape: {W1.shape} (2x4 matrix)")
print(f"Weight 2 shape: {W2.shape} (4x1 matrix)")
# Out:
# Architecture Defined!
# Weight 1 shape: (2, 4) (2x4 matrix)
# Weight 2 shape: (4, 1) (4x1 matrix)
