# %% [markdown]
# <a href="https://colab.research.google.com/github/halimAhtasham/DeepLearning/blob/main/Python_Program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
if(5>2):
  print("Yes")
# Out:
# Yes

# %%
x = 5
y = "Yes"
print(str(x) + " " + y)
# Out:
# 5 Yes

# %%
#print("Hello", end=' ')
#print("Hi")
#print("Bye")
#print("I am", 35, "years old")
#x, y, z = "Orange", "Banana", "Cherry"
#print(x , y, z);

fruits = {"apple", "banana", "orange"}
x, y, z = fruits
print(x, y, z)
# Out:
# apple orange banana

# %%
x = 3
def myfunc():
  x = 5
  print("I am in", x, "semester")
myfunc()
print("I am in", x, "semester")
# Out:
# I am in 5 semester
# I am in 3 semester

# %%
x = 3
def myfunc():
  global x
  x = 5
  print("I am in", x, "semester")
myfunc()
print("I am in", x, "semester")
# Out:
# I am in 5 semester
# I am in 5 semester
